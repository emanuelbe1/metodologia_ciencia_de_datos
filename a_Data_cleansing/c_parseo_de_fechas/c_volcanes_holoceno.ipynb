# %% [markdown]
# <hr>
# <p>Para un desafio extra, vamos a trabajar con un conjunto de datos del Smithsonian que documenta los volcanes de la tierra y su historial de erupciones sobre los ultimos 10mil años.</p>
#  Vamos a realizar un parseo de los datos de la columna "Last Known Eruption" del dataframe. Esta columna contiene una mezcla de texto("Unknown") y años antes de la era común (BCE, también conocida como BC) y en la era común (CE, también conocido cómo AD).

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import datetime

volcanes = pd.read_csv('datos/erupciones_volcanicas_holoceno/database.csv')

# %%
volcanes.head(3)
# Out:
#    Number                       Name  Country                          Region  \
# 0  210010  West Eifel Volcanic Field  Germany  Mediterranean and Western Asia
# 1  210020            Chaine des Puys   France  Mediterranean and Western Asia
# 2  210030        Olot Volcanic Field    Spain  Mediterranean and Western Asia
#
#                   Type  Activity Evidence Last Known Eruption  Latitude  \
# 0              Maar(s)     Eruption Dated            8300 BCE    50.170
# 1         Lava dome(s)     Eruption Dated            4040 BCE    45.775
# 2  Pyroclastic cone(s)  Evidence Credible             Unknown    42.170
#
#    Longitude  Elevation (Meters)                Dominant Rock Type  \
# 0       6.85                 600                           Foidite
# 1       2.97                1464             Basalt / Picro-Basalt
# 2       2.53                 893  Trachybasalt / Tephrite Basanite
#
#                           Tectonic Setting
# 0   Rift Zone / Continental Crust (>25 km)
# ...

# %%
volcanes[volcanes['Last Known Eruption']!='Unknown']
# Out:
#       Number                       Name         Country  \
# 0     210010  West Eifel Volcanic Field         Germany
# 1     210020            Chaine des Puys          France
# 3     210040   Calatrava Volcanic Field           Spain
# 4     211001                 Larderello           Italy
# 5     211003                    Vulsini           Italy
# ...      ...                        ...             ...
# 1498  390081             Montagu Island  United Kingdom
# 1499  390090                   Saunders  United Kingdom
# 1500  390100           Candlemas Island  United Kingdom
# 1503  390130                 Zavodovski  United Kingdom
# 1504  390140        Protector Seamounts  United Kingdom
#
#                               Region                 Type  Activity Evidence  \
# 0     Mediterranean and Western Asia              Maar(s)     Eruption Dated
# 1     Mediterranean and Western Asia         Lava dome(s)     Eruption Dated
# ...

# %% [raw]
# '''
# volcanos.columns
# date_lengths = volcanos['Last Known Eruption'].str.len()
# date_lengths.value_counts()
# indices = np.where([date_lengths == 7])[1]
# print('Indices with corrupted data:', indices)
# volcanos.loc[indices]
# # CD and AD common era
# import re
# for indice in date_lengths:
#     if re.findall('BCE', volcanos.loc[indice, 'Last Known Eruption']):
#
#         volcanos.loc[indice, 'Last Known Eruption'] = volcanos.loc[indice, 'Last Known Eruption'].replace('BCE', 'BC')
#     elif re.findall('CE', volcanos.loc[indice, 'Last Known Eruption']):
#
#         volcanos.loc[indice, 'Last Known Eruption'] = volcanos.loc[indice, 'Last Known Eruption'].replace('CE',' ')
#     elif re.findall('AD', volcanos.loc[indice, 'Last Known Eruption']):
#
#         volcanos.loc[indice, 'Last Known Eruption'] = volcanos.loc[indice, 'Last Known Eruption'].replace('AD',' ')
# '''
